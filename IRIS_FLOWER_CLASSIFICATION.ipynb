# %%
# Importing the library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the dataset

# %%
iris_data = pd.read_csv('/content/drive/MyDrive/IRIS.csv')

# %%
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Displaying basic information about the dataset

# %%
print("Preview of the dataset:")
print(iris_data.head())
# Out:
# Preview of the dataset:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
print("\nDataset Information:")
print(iris_data.info())
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
print("\nDataset Descriptive Statistics:")
print(iris_data.describe())
# Out:
# Dataset Descriptive Statistics:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Checking class distribution

# %%
print("\nClass Distribution:")
print(iris_data['species'].value_counts())
# Out:
# Class Distribution:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
# Checking for missing values

# %%
print("\nMissing Values:")
print(iris_data.isnull().sum())
# Out:
# Missing Values:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Visualizing class distribution using Countplot

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='species', data=iris_data, palette='turbo')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
# Visualizing feature distributions using Histograms

# %%
plt.figure(figsize=(12, 8))

# %%
iris_data['sepal_length'].hist()
# Out:
# <Axes: >

# %%
iris_data['sepal_width'].hist(color='lightgreen')
# Out:
# <Axes: >

# %%
iris_data['petal_length'].hist(color='pink')
# Out:
# <Axes: >

# %%
iris_data['petal_width'].hist(color='orange')
# Out:
# <Axes: >

# %%
# Exploring the relationship between species and sepal length using Boxplot

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x='species', y='sepal_length', data=iris_data.sort_values('sepal_length', ascending=False))
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
# Exploring the relationship between sepal width and sepal length using Scatter Plot

# %%
iris_data.plot(kind='scatter', x='sepal_width', y='sepal_length')
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
# Exploring the relationship between petal width and petal length using Scatter Plot

# %%
iris_data.plot(kind='scatter', x='petal_width', y='petal_length')
# Out:
# <Axes: xlabel='petal_width', ylabel='petal_length'>

# %%
# Exploring the relationship between sepal width and sepal length using Jointplot

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris_data, size=5)

# %%
# Exploring the relationship between petal width and petal length using Jointplot

# %%
sns.jointplot(x='petal_length', y='petal_width', data=iris_data, size=5)

# %%
sns.jointplot(x='sepal_length', y='sepal_width', data=iris_data, size=5)

# %%
# Visualizing pair-wise relationships between features using Pairplot

# %%
sns.pairplot(iris_data, hue='species', size=3)

# %%
# Calculating and displaying the correlation matrix

# %%
correlation_matrix = iris_data.corr()

# %%
correlation_matrix
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
# Visualizing the correlation matrix using Heatmap

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sns.heatmap(correlation_matrix, annot=True, ax=ax, cmap='cividis')
# Out:
# <Axes: >

# %%
# Splitting the dataset into training and testing sets

# %%
from sklearn.model_selection import train_test_split
X = iris_data.drop(columns=['species'])
Y = iris_data['species']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
# Building and evaluating K-Nearest Neighbors (KNN) model

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier()
knn_model.fit(X_train, Y_train)
accuracy_knn = knn_model.score(X_test, Y_test) * 100
print("Accuracy (KNN): ", accuracy_knn)
# Out:
# Accuracy (KNN):  97.77777777777777

# %%
# Building and evaluating Decision Tree model

# %%
from sklearn.tree import DecisionTreeClassifier
dct_model = DecisionTreeClassifier()
dct_model.fit(X_train, Y_train)
accuracy_dct = dct_model.score(X_test, Y_test) * 100
print("Accuracy (Decision Tree): ", accuracy_dct)
# Out:
# Accuracy (Decision Tree):  95.55555555555556

# %%
# Building and evaluating Logistic Regression model

# %%
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression()
lr_model.fit(X_train, Y_train)
accuracy_lr = lr_model.score(X_test, Y_test) * 100
print("Accuracy (Logistic Regression): ", accuracy_lr)
# Out:
# Accuracy (Logistic Regression):  97.77777777777777
